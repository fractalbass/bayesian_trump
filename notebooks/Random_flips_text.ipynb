# %%
import random
h=0
t=0
for x in range(1,10000):
    if (random.random()>0.5):
        flip="heads"
        h=h+1
    else:
        flip="tails"
        t=t+1
    print("|{0}|{1}|{2}|{3}".format(x,flip,h/x,t/x))
# Out:
# |1|tails|0.0|1.0
# |2|heads|0.5|0.5
# |3|tails|0.3333333333333333|0.6666666666666666
# |4|tails|0.25|0.75
# |5|tails|0.2|0.8
# |6|heads|0.3333333333333333|0.6666666666666666
# |7|tails|0.2857142857142857|0.7142857142857143
# |8|heads|0.375|0.625
# |9|heads|0.4444444444444444|0.5555555555555556
# |10|tails|0.4|0.6
# |11|heads|0.45454545454545453|0.5454545454545454
# |12|heads|0.5|0.5
# |13|tails|0.46153846153846156|0.5384615384615384
# |14|tails|0.42857142857142855|0.5714285714285714
# |15|heads|0.4666666666666667|0.5333333333333333
# |16|heads|0.5|0.5
# |17|heads|0.5294117647058824|0.47058823529411764
# |18|heads|0.5555555555555556|0.4444444444444444
# |19|tails|0.5263157894736842|0.47368421052631576
# |20|heads|0.55|0.45
# |21|heads|0.5714285714285714|0.42857142857142855
# |22|heads|0.5909090909090909|0.4090909090909091
# |23|tails|0.5652173913043478|0.43478260869565216
# |24|heads|0.5833333333333334|0.4166666666666667
# |25|tails|0.56|0.44
# ...
